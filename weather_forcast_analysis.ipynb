# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\dell\Downloads\weather.csv")

# %%
data
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
data.head()
# Out:
#    Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                0.00  2016-01-03           1             3       2016
# 1                0.00  2016-01-03           1             3       2016
# 2                0.16  2016-01-03           1             3       2016
# 3                0.00  2016-01-03           1             3       2016
# 4                0.01  2016-01-03           1             3       2016
#
#   Station.City Station.Code Station.Location Station.State  \
# 0   Birmingham          BHM   Birmingham, AL       Alabama
# 1   Huntsville          HSV   Huntsville, AL       Alabama
# 2       Mobile          MOB       Mobile, AL       Alabama
# 3   Montgomery          MGM   Montgomery, AL       Alabama
# 4    Anchorage          ANC    Anchorage, AK        Alaska
#
#    Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 0                         39                         46
# 1                         39                         47
# ...

# %%
data.shape
# Out:
# (16743, 14)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=16743, step=1)

# %%
data.columns
# Out:
# Index(['Data.Precipitation', 'Date.Full', 'Date.Month', 'Date.Week of',
#        'Date.Year', 'Station.City', 'Station.Code', 'Station.Location',
#        'Station.State', 'Data.Temperature.Avg Temp',
#        'Data.Temperature.Max Temp', 'Data.Temperature.Min Temp',
#        'Data.Wind.Direction', 'Data.Wind.Speed'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Data.Precipitation           float64
# Date.Full                     object
# Date.Month                     int64
# Date.Week of                   int64
# Date.Year                      int64
# Station.City                  object
# Station.Code                  object
# Station.Location              object
# Station.State                 object
# Data.Temperature.Avg Temp      int64
# Data.Temperature.Max Temp      int64
# Data.Temperature.Min Temp      int64
# Data.Wind.Direction            int64
# Data.Wind.Speed              float64
# dtype: object

# %%
data['Station.State'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'DE', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Puerto Rico', 'Rhode Island',
#        'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah',
#        'VA', 'Vermont', 'Virginia', 'Washington', 'West Virginia',
#        'Wisconsin', 'Wyoming'], dtype=object)

# %%
data.nunique()
# Out:
# Data.Precipitation            565
# Date.Full                      53
# Date.Month                     12
# Date.Week of                   31
# Date.Year                       2
# Station.City                  307
# Station.Code                  318
# Station.Location              318
# Station.State                  53
# Data.Temperature.Avg Temp     119
# Data.Temperature.Max Temp     125
# Data.Temperature.Min Temp     114
# Data.Wind.Direction            37
# Data.Wind.Speed              1461
# dtype: int64

# %%
data.count
# Out:
# <bound method DataFrame.count of        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
# ...

# %%
data.value_counts
# Out:
# <bound method DataFrame.value_counts of        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16743 entries, 0 to 16742
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Data.Precipitation         16743 non-null  float64
#  1   Date.Full                  16743 non-null  object
#  2   Date.Month                 16743 non-null  int64
#  3   Date.Week of               16743 non-null  int64
#  4   Date.Year                  16743 non-null  int64
#  5   Station.City               16743 non-null  object
#  6   Station.Code               16743 non-null  object
#  7   Station.Location           16743 non-null  object
#  8   Station.State              16743 non-null  object
#  9   Data.Temperature.Avg Temp  16743 non-null  int64
#  10  Data.Temperature.Max Temp  16743 non-null  int64
#  11  Data.Temperature.Min Temp  16743 non-null  int64
#  12  Data.Wind.Direction        16743 non-null  int64
# ...

# %%
#find all the unique wind speed values in data

data["Data.Wind.Speed"].nunique()
# Out:
# 1461

# %%
data["Data.Wind.Speed"].unique()
# Out:
# array([ 4.33,  3.86,  9.73, ..., 12.53, 19.98, 18.16], shape=(1461,))

# %%
#find the number of times when the wind speed was 4km/h
#data.head(2)
data[data["Data.Wind.Speed"]==4]
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 232                  0.01  2016-01-03           1             3       2016
# 531                  0.05  2016-01-10           1            10       2016
# 1155                 0.96  2016-01-24           1            24       2016
# 2572                 0.06  2016-02-28           2            28       2016
# 2648                 1.68  2016-02-28           2            28       2016
# 4331                 0.00  2016-04-03           4             3       2016
# 5307                 0.22  2016-04-24           4            24       2016
# 5515                 0.00  2016-05-01           5             1       2016
# 6000                 0.10  2016-05-15           5            15       2016
# 6297                 0.04  2016-05-15           5            15       2016
# 6335                 0.56  2016-05-22           5            22       2016
# ...

# %%
# find out all the null values
data.isnull()
# Out:
#        Data.Precipitation  Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                   False      False       False         False      False
# 1                   False      False       False         False      False
# 2                   False      False       False         False      False
# 3                   False      False       False         False      False
# 4                   False      False       False         False      False
# ...                   ...        ...         ...           ...        ...
# 16738               False      False       False         False      False
# 16739               False      False       False         False      False
# 16740               False      False       False         False      False
# 16741               False      False       False         False      False
# 16742               False      False       False         False      False
#
#        Station.City  Station.Code  Station.Location  Station.State  \
# ...

# %%
data.isnull().sum()
# Out:
# Data.Precipitation           0
# Date.Full                    0
# Date.Month                   0
# Date.Week of                 0
# Date.Year                    0
# Station.City                 0
# Station.Code                 0
# Station.Location             0
# Station.State                0
# Data.Temperature.Avg Temp    0
# Data.Temperature.Max Temp    0
# Data.Temperature.Min Temp    0
# Data.Wind.Direction          0
# Data.Wind.Speed              0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Data.Precipitation           16743
# Date.Full                    16743
# Date.Month                   16743
# Date.Week of                 16743
# Date.Year                    16743
# Station.City                 16743
# Station.Code                 16743
# Station.Location             16743
# Station.State                16743
# Data.Temperature.Avg Temp    16743
# Data.Temperature.Max Temp    16743
# Data.Temperature.Min Temp    16743
# Data.Wind.Direction          16743
# Data.Wind.Speed              16743
# dtype: int64

# %%
# rename the column name 
data.rename(columns={"Data.Wind.Speed":"Speed"})
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
data.rename(columns={"Data.Wind.Speed":"Speed"},inplace=True)

# %%
#what is the mean of data.avg temp?
#data.head(2)
data.Speed.mean()
# Out:
# np.float64(6.3298202233769345)

# %%
#what is standard deviation of speed
data.Speed.std()
# Out:
# np.float64(3.4947852525194727)

# %%
# what is the variance of speed
data.Speed.var()
# Out:
# np.float64(12.213523961227596)

# %%
data.head(3)
# Out:
#    Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                0.00  2016-01-03           1             3       2016
# 1                0.00  2016-01-03           1             3       2016
# 2                0.16  2016-01-03           1             3       2016
#
#   Station.City Station.Code Station.Location Station.State  \
# 0   Birmingham          BHM   Birmingham, AL       Alabama
# 1   Huntsville          HSV   Huntsville, AL       Alabama
# 2       Mobile          MOB       Mobile, AL       Alabama
#
#    Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 0                         39                         46
# 1                         39                         47
# 2                         46                         51
#
#    Data.Temperature.Min Temp  Data.Wind.Direction  Speed
# 0                         32                   33   4.33
# 1                         31                   32   3.86
# ...

# %%
# find all inctances when speed is above 6 and avg temperature is 35
data[(data["Speed"] >6) & (data["Data.Temperature.Avg Temp"] ==35)]
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 104                  0.00  2016-01-03           1             3       2016
# 121                  0.00  2016-01-03           1             3       2016
# 162                  0.00  2016-01-03           1             3       2016
# 225                  0.00  2016-01-03           1             3       2016
# 333                  0.04  2016-01-10           1            10       2016
# ...                   ...         ...         ...           ...        ...
# 16528                0.44  2017-01-01           1             1       2017
# 16537                0.00  2017-01-01           1             1       2017
# 16563                0.95  2017-01-01           1             1       2017
# 16631                0.22  2017-01-01           1             1       2017
# 16650                0.77  2017-01-01           1             1       2017
#
# ...

# %%
data.groupby("Station.State").mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1943, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1942 try:
# -> 1943     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1944 except Exception as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# ...
